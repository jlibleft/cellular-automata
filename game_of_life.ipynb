# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd
import pygame
# Out:
# pygame 2.6.1 (SDL 2.32.64, Python 3.14.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# <frozen importlib._bootstrap>:491: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.

# %%
def generate_coordiantes(n):
    return rd.choices(range(0, 450, 50),k=n)

# %%
c_x,c_y=generate_coordiantes(25),generate_coordiantes(25)

# %%
pygame.init()
grid_x, grid_y = 500,500
board = np.zeros(((grid_x,grid_y)))
screen = pygame.display.set_mode((grid_x,grid_y))
clock = pygame.time.Clock()
running = True
interval = 1300
next_toggle = pygame.time.get_ticks() + interval
show_rectangle = True
first_time = True



while running:
    frame = pygame.surfarray.make_surface(board * 255)
    current_time = pygame.time.get_ticks()
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    if first_time:
        board[:,:] = 255
        screen.blit(frame, (0, 0))
        pygame.display.flip()
        print("pierwszy")
        first_time = False

    if current_time >= next_toggle:
        show_rectangle = not show_rectangle
        next_toggle = current_time + interval
        print(f"dupa {show_rectangle}")
        board.fill(0)
        
    if show_rectangle AND first_time==False:
        for i in range(25):
            board[c_y[i]:c_y[i]+50,c_x[i]:c_x[i]+50]=1

    
    for y in range(0,500,50):
        pygame.draw.line(frame, (60, 179, 113), [0,y], [grid_y, y], 1)
    for x in range(0,500,50):
        pygame.draw.line(frame, (60, 179, 113), [x,0], [x, grid_x], 1)
    

    screen.blit(frame, (0, 0))
    pygame.display.flip()

    clock.tick(60) 

pygame.quit()
# Out:
#   Cell In[7], line 34
#     if show_rectangle AND first_time==False:
#                       ^
# SyntaxError: invalid syntax
